# %% [markdown]
# **FILES, EXCEPTION HANDLING, LOGGING AND MEMORY MANAGEMENT QUESTIONS**
#
#
#
#
#
#
# Ans 1. The main difference between interpreted and compiled languages is how the code is executed:
# Compiled languages
# The entire code is converted into machine language before execution. This results in more efficient code that can be executed multiple times.
# Interpreted languages
# The code is executed line by line, without a separate compilation step. This makes it easier and faster to develop and test code.
#
# Ans 2. Exception handling in Python is a way to prepare for and deal with errors that can occur while a program is running. It's a crucial part of writing reliable code and improving the user experience.
#
# Ans 3. The purpose of a finally block in exception handling is to ensure that important code is executed regardless of whether an exception is thrown. This is useful for performing cleanup actions like closing files or releasing resources.
#
# Ans 4. Python logging is a module that allows you to track events that occur while your program is running.
#
# Ans 5. The __del__() method in Python is a destructor method that is called when an object is about to be destroyed. It is a powerful tool that helps manage resource cleanup when objects are destroyed.
#
# Ans 6. The difference between import and from import in Python is: import imports an entire code library. from import imports a specific member or members of the library.
#
# Ans 7- In Python, you can handle multiple exceptions using try-except blocks. Here are some ways to handle multiple exceptions in Python:
# Use a single except clause
# Use multiple except blocks
# use an else cause
#
# Ans 8- The with statement in Python is used to simplify the management of resources that need to be acquired and released in a specific order. It provides a way to wrap the execution of a block of code with methods defined by a context manager.
#
# Ans9- Multithreading refers to the ability of a processor to execute multiple threads concurrently, where each thread runs a process. Multiprocessing refers to the ability of a system to run multiple processors in parallel, where each processor can run one or more threads.
#
# Ans 10- advantages
# a. It helps debug errors easily.
# b. It's more perceptive than traceback methods.
# c. It can be used to save info on warnings, errors and other events.
#
# Ans 11- The memory manager is responsible for allocating memory to Python objects and tracking which objects are currently in use. Python has two types of memory that it uses: stack memory and heap memory.
#
# Ans 12- The basic steps for exception handling in Python are:
# Use the try() function: The try() function is used to catch and handle exceptions that may occur while a block of code is executing.
#
# Use the except block: The except block is used to execute code and handle exceptions that arise.
#
# Use the else block: The else block runs if no exceptions were raised in the try block.
#
# Use the try-except-finally block: The try-except-finally block is the primary mechanism for exception handling in Python. It allows you to catch exceptions, handle them gracefully, and execute cleanup code.
#
# Ans 13- Memory management is important in Python because it helps write efficient code, reduce the risk of errors and crashes, and improve program performance:
#
# efficient code
#
# fewer errors and crashes
#
# Ans 14- Use the try-except-finally block: The try-except-finally block is the primary mechanism for exception handling in Python. It allows you to catch exceptions, handle them gracefully, and execute cleanup code.
#
# Ans 15- Python's garbage collection system automatically manages memory by detecting and removing objects that are no longer in use. It uses a combination of mechanisms to do this, including:
#
# a. reference counting
#
# b. generational garbage collection
#
# Ans 16-Use the else block: The else block runs if no exceptions were raised in the try block.
#
# Ans 17- Python's logging module has six standard logging levels that indicate the severity of an event:
#
# a. notset
#
# b. debug
#
# c. info
#
# d. warning
#
# e. error
#
# f. critical
#
# Ans 18- The main difference between forking and multiprocessing in Python is that forking creates a new process that's a copy of the current process, while multiprocessing starts a new Python interpreter process
#
# Ans 19- Because files are limited resources managed by the operating system, making sure files are closed after use will protect against hard-to-debug issues like running out of file handles or experiencing corrupted data.
#
# Ans 20. The `read()` method will read the entire content of the file or stream if no argument is provided, returning a string. On the other hand, the `readline()` method reads a single line up to the newline character (`\n`) and returns it as a string.
#
# Ans 21-Python logging is a module that allows you to track events that occur while your program is running.
#
# Ans 22- File handling in an operating system refers to the process of creating, reading, updating, and deleting files.
#
# Ans23- Some challenges with memory management in Python include:
#
# a. memory leaks
#
# b. ineffective memory management
#
# c.accidental overwriting in memory
#
# Ans 24- To throw (or raise) an exception, use the raise keyword.
#
# Ans 25- multithreading is important in certain applications because it can improve performance, responsiveness, and resource utilization.
#
#
#
#
#
# **PRACTICAL QUESTIONS**

# %%
Ans. 1-- # Open the file in write mode ('w'). If the file doesn't exist, it will be created.
# If it exists, it will be overwritten.
file = open('my_file.txt', 'w')

# Write the string to the file.
file.write('This is the string I want to write to the file.')

# Close the file to save the changes.
file.close()

# %%
Ans 2- def read_and_print_file(file_path):
  """Reads a file and prints each line.

  Args:
    file_path: The path to the file to read.
  """
  try:
    with open(file_path, 'r') as file:
      for line in file:
        print(line, end='')  # Print the line without an extra newline
  except FileNotFoundError:
    print(f"Error: File not found at path: {file_path}")
  except Exception as e:
    print(f"An error occurred: {e}")

# Example usage:
file_path = 'my_file.txt'  # Replace with the actual file path
read_and_print_file(file_path)

# %%
Ans 3-import os

def read_file_safely(file_path):
  """Reads a file and prints its contents, handling file not found errors.

  Args:
    file_path: The path to the file to read.
  """
  if not os.path.exists(file_path):
    print(f"Error: File not found at path: {file_path}")
    return  # Exit the function if the file doesn't exist

  try:
    with open(file_path, 'r') as file:
      # Process the file content here
      for line in file:
          print(line, end='')
  except Exception as e:
    print(f"An error occurred while reading the file: {e}")

# Example usage
file_path = 'my_file.txt'
read_file_safely(file

# %%
Ans 4def copy_file_content(source_file, destination_file):
  """Reads content from source_file and writes it to destination_file.

  Args:
    source_file: The path to the source file.
    destination_file: The path to the destination file.
  """
  try:
    with open(source_file, 'r') as source, open(destination_file, 'w') as destination:
      for line in source:
        destination.write(line)
    print(f"Content copied from '{source_file}' to '{destination_file}' successfully.")
  except FileNotFoundError:
    print(f"Error: Source file '{source_file}' not found.")
  except Exception as e:
    print(f"An error occurred: {e}")

# Example usage
source_file = 'input.txt'
destination_file = 'output.
-

# %%
Ans 5- def divide_numbers(numerator, denominator):
  """Divides two numbers and handles ZeroDivisionError.

  Args:
    numerator: The numerator.
    denominator: The denominator.

  Returns:
    The result of the division, or an error message if denominator is 0.
  """
  try:
    result = numerator / denominator
    return result
  except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
    return None  # or any other appropriate value

# Example usage
num1 = 10
num2 = 0

result = divide_numbers(num1, num2)

if result is not None:
  print(f"Result: {result}")

# %%
Ans6-import logging

def divide_numbers(numerator, denominator):
    """Divides two numbers and logs an error if a ZeroDivisionError occurs."""
    try:
        result = numerator / denominator
        return result
    except ZeroDivisionError:
        logging.error("Division by zero occurred")
        return None

# Configure logging
logging.basicConfig(filename='error.log', level=logging.ERROR,
                    format='%(asctime)s - %(levelname)s - %(message)s')

# Example usage
num1 = 10
num2 = 0

result = divide_numbers(num1, num2)

if result is not None:
    print(f"Result: {result}")
else:
    print("An error occurred. See error.log for details.")

# %%
Ans 7- import logging

# Configure logging
logging.basicConfig(filename='my_log.log', level=logging.DEBUG,  # Log all levels
                    format='%(asctime)s - %(levelname)s - %(message)s')

# Log messages at different levels
logging.info("This is an informational message.")
logging.warning("This is a warning message.")
logging.error("This is an error message.")
logging.debug("This is a debug message.")  # Will be logged because level is DEBUG

# %%
Ans 8- def read_file(file_path):
  """Reads a file and prints its contents, handling file opening errors.

  Args:
    file_path: The path to the file to read.
  """
  try:
    with open(file_path, 'r') as file:
      # Process the file content here (e.g., print it)
      for line in file:
        print(line, end='')
  except FileNotFoundError:
    print(f"Error: File not found at path: {file_path}")
  except IOError:  # Handles other file opening errors (e.g., permission errors)
    print(f"Error: Could not open file: {file_path}")
  except Exception as e:
    print(f"An unexpected error occurred: {e}")

# Example usage
file_path = 'my_file.txt'  # Replace with the actual

# %%
Ans 9- def read_file_to_list(file_path):
  """Reads a file line by line and stores its content in a list.

  Args:
    file_path: The path to the file to read.

  Returns:
    A list containing each line of the file as a separate element,
    or None if an error occurs.
  """
  try:
    with open(file_path, 'r') as file:
      lines = file.readlines()  # Read all lines into a list
    return lines
  except FileNotFoundError:
    print(f"Error: File not found at path: {file_path}")
    return None
  except Exception as e:
    print(f"An error occurred: {e}")
    return None

# Example usage
file_path = 'my_file.txt'  # Replace with the actual file path

# %%
Ans 10- def append_to_file(file_path, data):
  """Appends data to an existing file.

  Args:
    file_path: The path to the file.
    data: The data to append to the file.
  """
  try:
    with open(file_path, 'a') as file:  # Open in append mode ('a')
      file.write(data)
    print(f"Data appended to '{file_path}' successfully.")
  except FileNotFoundError:
    print(f"Error: File not found at path: {file_path}")
  except Exception as e:
    print(f"An error occurred: {e}")

# Example usage
file_path = 'my_file.txt'  # Replace with the actual file path
data_to_append = "\nThis is the data to append."

append_to_file(file_path,

# %%
Ans 11- def access_dictionary_key(dictionary, key):
  """Accesses a dictionary key and handles KeyError if the key doesn't exist.

  Args:
    dictionary: The dictionary to access.
    key: The key to access.

  Returns:
    The value associated with the key if it exists, otherwise None.
  """
  try:
    value = dictionary[key]
    return value
  except KeyError:
    print(f"Error: Key '{key}' not found in the dictionary.")
    return None

# Example usage
my_dict = {'a': 1, 'b': 2, 'c': 3}

# Accessing an existing key
value = access_dictionary_key(my_dict, 'b')
if value is not None:
  print(f"Value for key 'b':)

# %%
Ans 12-def handle_different_errors():
    """Demonstrates handling different exceptions with multiple except blocks."""
    try:
        # Case 1: Potential FileNotFoundError
        with open("nonexistent_file.txt", "r") as file:
            content = file.read()
            print(content)

        # Case 2: Potential TypeError
        result = 10 + "hello"
        print(result)

    except FileNotFoundError:
        print("Error: File not found.")
    except TypeError:
        print("Error: Invalid operation. Cannot add a number and a string.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# Call the error handling function
handle_different_errors()

# %%
Ans 13- import os

def read_file_if_exists(file_path):
  """Reads a file if it exists, otherwise prints an error message.

  Args:
    file_path: The path to the file.
  """
  if os.path.exists(file_path):
    try:
      with open(file_path, 'r') as file:
        # Process the file content here (e.g., print it)
        for line in file:
            print(line, end='')

    except Exception as e:
      print(f"An error occurred while reading the file: {e}")
  else:
    print(f"Error: File '{file_path}' does not exist.")

# Example usage
file_path = 'my_file.txt'  # Replace with the actual file path
read_file_if_exists(file_path)

# %%
Ans 14- import os

def print_file_content(file_path):
    """Prints the content of a file, handling the case when the file is empty."""
    if not os.path.exists(file_path):
        print(f"Error: File '{file_path}' does not exist.")
        return

    with open(file_path, 'r') as file:
        content = file.read()
        if content:  # Check if content is not empty
            print(content)
        else:
            print(f"File '{file_path}' is empty.")

# Example usage
file_path = 'my_file.txt'  # Replace with the actual file path
print_file_content(file_path)

# %%
Ans 15- import os

def print_file_content(file_path):
    """Prints the content of a file, handling the case when the file is empty."""
    if not os.path.exists(file_path):
        print(f"Error: File '{file_path}' does not exist.")
        return

    with open(file_path, 'r') as file:
        content = file.read()
        if content:  # Check if content is not empty
            print(content)
        else:
            print(f"File '{file_path}' is empty.")

# Example usage
file_path = 'my_file.txt'  # Replace with the actual file path
print_file_content(file_path)

# %%
Ans 16- !pip install memory_profiler==0.61.0  # Install memory_profiler

import memory_profiler
import time

@memory_profiler.profile  # Decorate the function to profile
def my_function():
    """A simple function to demonstrate memory profiling."""
    data = [i * 2 for i in range(100000)]  # Create a large list
    time.sleep(2)  # Simulate some work
    del data  # Delete the list to free memory

if __name__ == "__main__":
    my_function()

# %%
Ans 17- def write_numbers_to_file(file_path, numbers):
  """Writes a list of numbers to a file, one number per line.

  Args:
    file_path: The path to the file to write to.
    numbers: The list of numbers to write.
  """
  try:
    with open(file_path, 'w') as file:
      for number in numbers:
        file.write(str(number) + '\n')  # Convert number to string and add newline
    print(f"Numbers written to '{file_path}' successfully.")
  except Exception as e:
    print(f"An error occurred: {e}")

# Example usage
file_path = 'numbers.txt'
numbers = [1, 2, 3, 4, 5]

write_numbers_to_file(file_path,

# %%
Ans 18- import logging
from logging.handlers import RotatingFileHandler

def setup_logging():
    """Sets up logging to a file with rotation."""
    logger = logging.getLogger(__name__)  # Get the logger for the current module
    logger.setLevel(logging.DEBUG)  # Set the logging level

    # Create a RotatingFileHandler
    handler = RotatingFileHandler('my_log.log', maxBytes=1024 * 1024, backupCount=5)
    handler.setLevel(logging.DEBUG)  # Set the level for the handler

    # Create a formatter and add it to the handler
    formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    handler.setFormatter(formatter)

    # Add the handler to the logger
    logger.addHandler(handler)

    return logger

# Example

# %%
Ans 19- def handle_errors(data_structure, index_or_key):
    """Handles IndexError and KeyError using a try-except block.

    Args:
        data_structure: A list or dictionary.
        index_or_key: The index (for list) or key (for dictionary) to access.
    """
    try:
        if isinstance(data_structure, list):
            value = data_structure[index_or_key]  # Access list element
        elif isinstance(data_structure, dict):
            value = data_structure[index_or_key]  # Access dictionary value
        else:
            raise TypeError("Invalid data structure. Must be a list or dictionary.")

        print(f"Value: {value}")

    except IndexError:
        print(f"Error: Index '{index_or_key}' is out of range for the list.")
    except KeyError:
        print(f"Error: Key '{index_or_key}' not found in the dictionary.")
    except TypeError as e:
        print(e)  # Print the TypeError message
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# Example usage with a list
my_list = [10, 20, 30]
handle_errors(my_list, 3)  # This will raise an IndexError

# Example usage with a dictionary
my_dict = {'a': 1, 'b': 2, 'c': 3}
handle_errors(my_dict, 'd')  # This will raise a KeyError

# %%
Ans 20- def read_file_with_context_manager(file_path):
    """Opens a file, reads its content using a context manager, and prints the content.

    Args:
        file_path: The path to the file.
    """
    try:
        with open(file_path, 'r') as file:
            content = file.read()
            print(content)
    except FileNotFoundError:
        print(f"Error: File not found at path: {file_path}")
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage
file_path = 'my_file.txt'  # Replace with the actual file path
read_file_with_context_manager(file_path)

# %%
Ans 21- import re

def count_word_occurrences(file_path, word):
  """Reads a file and counts the occurrences of a specific word.

  Args:
    file_path: The path to the file.
    word: The word to count.

  Returns:
    The number of occurrences of the word in the file.
  """
  try:
    with open(file_path, 'r') as file:
      content = file.read()
      # Use regular expression to find all occurrences of the word (case-insensitive)
      occurrences = len(re.findall(r'\b' + word + r'\b', content, re.IGNORECASE))
      return occurrences
  except FileNotFoundError:
    print(f"Error: File not found at path: {file_path}")
    return 0
  except Exception as e:
    print(f"An error occurred: {e}")
    return 0

# Example usage
file_path = 'my_file.txt'  # Replace with your file path
word_to_count = 'example'

count = count_word_occurrences(file_path, word_to_count)
print(f"The word '{word_to_count}' appears {count} times in the file.")

# %%
Ans 22- import os

def is_file_empty(file_path):
  """Checks if a file is empty.

  Args:
    file_path: The path to the file.

  Returns:
    True if the file is empty, False otherwise.
  """
  return os.stat(file_path).st_size == 0

# Example usage
file_path = 'my_file.txt'  # Replace with your file path

if is_file_empty(file_path):
  print(f"File '{file_path}' is empty.")
else:
  # Proceed to read the file content
  with open(file_path, 'r') as file:
    content = file.read()
    # ... (process the content) ...

# %%
Ans 23- import logging

def process_file(file_path):
    """Processes a file and logs errors to a log file."""
    try:
        with open(file_path, 'r') as file:
            # Perform file operations here (e.g., read, write)
            content = file.read()
            # ... (process content) ...
    except FileNotFoundError:
        logging.error(f"File not found: {file_path}")
    except IOError as e:
        logging.error(f"I/O error while processing file: {file_path}, Error: {e}")
    except Exception as e:
        logging.exception(f"An unexpected error occurred while processing file: {file_path}")

# Configure logging
logging.basicConfig(filename='file_handling_errors.log', level=logging.ERROR,
                    format='%(asctime)s - %(levelname)s - %(message)s')
 # Example usage
file_path = 'my_file.txt'  # Replace with your file path
process_file(file_path)
